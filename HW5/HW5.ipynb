# %% [markdown]
# Load all neaded modules.

# %%
from Data_modules import DataLoader, Visualizer, ModelRegressor, ModelMetrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Load insurance data.

# %%
datahandler = DataLoader()
trainer = ModelRegressor()
metrics = ModelMetrics()
enc = OrdinalEncoder()

insurance_df = datahandler.load_data('Data/insurance.csv')

insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Data preprocessing.

# %%
enc.fit(insurance_df[['sex', 'smoker', 'region']])


insurance_df[['sex', 'smoker', 'region']] = enc.transform(insurance_df[['sex', 'smoker', 'region']])
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19  0.0  27.900         0     1.0     3.0  16884.92400
# 1      18  1.0  33.770         1     0.0     2.0   1725.55230
# 2      28  1.0  33.000         3     0.0     2.0   4449.46200
# 3      33  1.0  22.705         0     0.0     1.0  21984.47061
# 4      32  1.0  28.880         0     0.0     1.0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50  1.0  30.970         3     0.0     1.0  10600.54830
# 1334   18  0.0  31.920         0     0.0     0.0   2205.98080
# 1335   18  0.0  36.850         0     0.0     2.0   1629.83350
# 1336   21  0.0  25.800         0     0.0     3.0   2007.94500
# 1337   61  0.0  29.070         0     1.0     1.0  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Preparing train and test data for models.

# %%
X = insurance_df.drop('charges', axis=1)
y = insurance_df['charges']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
result = trainer.get_all_models(X_train, X_test, y_train)

# %% [markdown]
# Evaluating models results.

# %%
metrics_result = metrics.get_all_models_metrics(y_test, result)
# Out:
# ----------------------
# Gradient Boosting model metrics:
# MSE: 25479912.9500
# MAE: 2785.3715
# R2: 0.8358
# ----------------------
# ----------------------
# Ada Boost model metrics:
# MSE: 30775697.9906
# MAE: 4592.1421
# R2: 0.8017
# ----------------------
# ----------------------
# Extra Trees model metrics:
# MSE: 27242700.8539
# MAE: 2695.5362
# R2: 0.8244
# ----------------------
# ----------------------
# K Neighbors model metrics:
# MSE: 144491759.3383
# MAE: 8229.3349
# R2: 0.0688
# ----------------------
# ----------------------
# Decision Tree model metrics:
# MSE: 38796381.1790
# MAE: 2896.1118
# R2: 0.7500
# ----------------------
# ----------------------
# SVM model metrics:
# MSE: 174528716.2303
# MAE: 8462.5012
# R2: -0.1248
# ----------------------
# ----------------------
# eXtreme GBM model metrics:
# MSE: 31387912.3189
# MAE: 3274.3859
# R2: 0.7977
# ----------------------
# ----------------------
# Light GBM model metrics:
# MSE: 26176865.5145
# ...

# %% [markdown]
# Checking R2 metric.

# %%
metrics.get_all_models_r2()
# Out:
# {'SVM': '-0.1248',
#  'K Neighbors': '0.0688',
#  'Decision Tree': '0.7500',
#  'eXtreme GBM': '0.7977',
#  'Ada Boost': '0.8017',
#  'Extra Trees': '0.8244',
#  'Cat Boost': '0.8292',
#  'Light GBM': '0.8313',
#  'Gradient Boosting': '0.8358'}

# %% [markdown]
# According to this results - Gradient Boosting models works best.
